# %% [markdown]
# # Data Visualisation
# This Jupyter Notebook is meant to help us visualise and analyse the data from traindata.txt and trainlabels.txt. Ensure you have downloaded the text files from Moodle and that you include their directories into this notebook otherwise your code won't run. GitHub doesn't allow for very large file uploads and frankly trying to find a way around this is an unnecessary fight since we all can get copies of the same data on the click of a button. Furthermore, ensure you use the prescribed libraries as seen in the instruction brief. The first part I wrote contains simple visualisation code you can mess with to get you started. Happy coding :)
#
# #### Imports

# %%
# pip install pandas==2.2.2

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_54756\3267135575.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #### Reading the data
# Ensure you change the traindata.txt to reference a file on your device or wherever you chose to put it.

# %%
data = pd.read_csv('C:\\Users\\User\\Documents\\CS Year 3\\ML\\Assignment 2\\traindata.txt', header=None)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

data.head(10)
# data.tail(10)
# Out:
#         0          1          2          3          4          5     \
# 0  33.167786   9.462100  50.246693  24.813057  29.595383   6.788610
# 1  33.347870  72.296570  49.780758  21.914070  11.955104   8.121966
# 2   2.140534  66.103172  14.212941  18.855560  55.134956  14.152965
# 3  38.091331  62.345455  37.483807  25.661188  11.391671  35.225670
# 4  42.160133  25.208063  68.065666  48.452103  54.928009   7.298090
# 5  61.942860  45.253212  56.602798   4.468305  26.931870  34.870155
# 6  50.999130  49.402901  44.573597  54.692806  39.878853  49.045494
# 7  13.118728  13.963515  32.560360  50.597729  39.013840  74.231270
# 8  21.540049  33.443729  45.643333  55.084106  33.016300  41.600788
# 9  41.700890  41.110439  40.806675  74.804398  62.647758  65.351265
#
#         6          7          8          9          10         11    \
# 0  10.017276  36.381538  65.653381  46.273445  44.087254  16.133245
# 1  70.963631  60.014278  12.690736  71.657326  14.301578  13.984180
# ...

# %%
tuple_size = data.shape[1]
num_datapoints = data.shape[0]

data.shape, num_datapoints, tuple_size
# Out:
# ((5250, 1041), 5250, 1041)

# %% [markdown]
# #### Data Information
# Pandas gives some simple review statistics/information about performance and the data itself

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Columns: 1041 entries, 0 to 1040
# dtypes: float64(1041)
# memory usage: 41.7 MB

# %% [markdown]
# #### Reading the data labels
# Remember to change the filename to a directory on your device.

# %%
labels = pd.read_csv('C:\\Users\\User\\Documents\\CS Year 3\\ML\\Assignment 2\\trainlabels.txt', header=None)

# %%
labels.head()
# Out:
#     0
# 0  11
# 1   1
# 2  10
# 3   7
# 4  18

# %% [markdown]
# #### Separate Data Labels
# A weird thing about the traindata.txt file is that in the last column, it has some labels: 0, 1, 2, 3. This suggests that the data is already labelled. I initially suspected that the data is generated from 4 clusters and each cluster defines 5 different classes which gives rise to the 20 different classes we have in the trainlabels.txt. However, this is a suspicion/theory. Try out your own and see how far you get. Have fun:)

# %%
data[tuple_size - 1].value_counts()
# Out:
# 1040
# 2.0    1332
# 0.0    1328
# 1.0    1308
# 3.0    1282
# Name: count, dtype: int64

# %%
data[tuple_size - 1].unique()
# Out:
# array([2., 1., 0., 3.])
